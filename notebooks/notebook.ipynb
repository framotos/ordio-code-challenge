# %%
# === Install dependencies ===
# %pip install openai faiss-cpu pandas numpy transformers python-dotenv

# %%
# === Preconfiguration: imports & stubs ===

import os
import glob
from dotenv import load_dotenv

import openai
import faiss
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel

# Load API key
openai.api_key = "YOUR_CUSTOM_API_KEY"

# Embed & Index

# Retrieval & Prompting

# Evaluation
